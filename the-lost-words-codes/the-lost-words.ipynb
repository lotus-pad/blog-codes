# %%
import pandas as pd

# %% [markdown]
# # PEN data

# %%
# reading a csv file and convertingto a dataframe
df = pd.read_csv("PEN-America's-Index-of-School-Book-Bans-2022-2023.csv", header = 2) #bc the first two rows are empty/filled with unnecessary cells
df.head()
# Out:
#                                                Title                  Author  \
# 0  Liar, Temptress, Soldier, Spy: Four Women Unde...           Abbott, Karen
# 1                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 2                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 3                                      Ace of Spades  Àbíké-Íyímídé, Faridah
# 4                                      Ace of Spades  Àbíké-Íyímídé, Faridah
#
#   Secondary Author(s) Illustrator(s) Translator(s) Series Name    State  \
# 0                 NaN            NaN           NaN         NaN    Texas
# 1                 NaN            NaN           NaN         NaN  Florida
# 2                 NaN            NaN           NaN         NaN  Florida
# 3                 NaN            NaN           NaN         NaN  Florida
# 4                 NaN            NaN           NaN         NaN  Florida
#
#                              District Date of Challenge/Removal  \
# ...

# %%
# i just wanna see the headers
df[:1] 
# type(df[:0])
# Out:
#                                                Title         Author  \
# 0  Liar, Temptress, Soldier, Spy: Four Women Unde...  Abbott, Karen
#
#   Secondary Author(s) Illustrator(s) Translator(s) Series Name  State  \
# 0                 NaN            NaN           NaN         NaN  Texas
#
#                              District Date of Challenge/Removal  \
# 0  Frisco Independent School District              October 2022
#
#                      Ban Status Origin of Challenge
# 0  Banned Pending Investigation      Administration

# %%
df.Author
df.Title
# Out:
# 0       Liar, Temptress, Soldier, Spy: Four Women Unde...
# 1                                           Ace of Spades
# 2                                           Ace of Spades
# 3                                           Ace of Spades
# 4                                           Ace of Spades
#                               ...
# 3357                     My Life as an Ice Cream Sandwich
# 3358                                     Punching the Air
# 3359                Poisonous, Smelly, and Amazing Plants
# 3360                Bosch: The Garden of Earthly Delights
# 3361             How to Read Italian Renaissance Painting
# Name: Title, Length: 3362, dtype: object

# %%
# drop all the duplicates
df = df.drop_duplicates(subset=['Title', 'Author'])
df ###perfect!!!!!
# Out:
#                                                   Title  \
# 0     Liar, Temptress, Soldier, Spy: Four Women Unde...
# 1                                         Ace of Spades
# 5                                    Clap When You Land
# 6                                            The Poet X
# 14         Uncomfortable Conversations with a Black Boy
# ...                                                 ...
# 3357                   My Life as an Ice Cream Sandwich
# 3358                                   Punching the Air
# 3359              Poisonous, Smelly, and Amazing Plants
# 3360              Bosch: The Garden of Earthly Delights
# 3361           How to Read Italian Renaissance Painting
#
#                       Author Secondary Author(s) Illustrator(s) Translator(s)  \
# 0              Abbott, Karen                 NaN            NaN           NaN
# 1     Àbíké-Íyímídé, Faridah                 NaN            NaN           NaN
# ...

# %% [markdown]
# ## End Goal:
# the next step i wanna do is make **visuals**:
# * school book bans by state
# * unique numbers of books per state
# * Top banned books, sorted by number of unique school districts each was banned in.
# * Proportion of banned books by age group and by genre.
# * Histogram showing distribution of book publication year.
# * Histogram showing page number distribution of banned books.
# * Number of unique school districts each author was banned in. Authors who are White and identify as men are colored in yellow.
# * Top topics found in banned book descriptions.
#
# ##### notes too self:
# **but before that**, i need to find the following of each banned book from PEN using google books:
#     # book pages
#     # proportion of banned books by age group and by genre
#
# i remember from last time, the only thing that i needed from the whole indexes of the data
# from google books API was volumneInfo so I might stick to that
# the things that

# %% [markdown]
# # google API

# %%
from pathlib import Path
import requests
import time

# %%
# api key
file_path = Path.home() / "Desktop"/ "winter2025"/ "stat386" / "api-keys" / "google-books-api-key.txt"

if file_path.exists():
        with file_path.open("r") as file:
            books_key = file.read().strip()
else:
        print("API key file not found!")

# %%
# This request has a single required parameter:

# q - Search for volumes that contain this text string. There are special keywords you can specify in the search terms to search in particular fields, such as:
    # intitle: Returns results where the text following this keyword is found in the title.
    # inauthor: Returns results where the text following this keyword is found in the author.
    # inpublisher: Returns results where the text following this keyword is found in the publisher.
    # subject: Returns results where the text following this keyword is listed in the category list of the volume.
    # isbn: Returns results where the text following this keyword is the ISBN number.
    # lccn: Returns results where the text following this keyword is the Library of Congress Control Number.
    # oclc: Returns results where the text following this keyword is the Online Computer Library Center number.

# %%
url = 'https://www.googleapis.com/books/v1/volumes'

# %%
### testing with just one title!!
# params = {
#     'q': 'Ace of Spades',
#     'key':books_key
# }

# r = requests.get(url, params = params)
# r.text

# authors don't match up :/

# %%
### side-quest: try and get just the volumeInfo from the API bc that's all i want! 
# for title in df.Title:
#     query = title
    
#     params = {
#         'q': 'title',
#         'fields': 'items(volumeInfo)',
#         'key': books_key
#     }

#     r = requests.get(url, params=params)

#     if r.ok:
#         data = r.json()

# this is great for just the title but i want the author to match up asw!

# %%
### now back to the main idea! trying to just get the book from the CORRECT author
all_books = []

title = 'Ace of Spades'
author = 'Faridah'

# Combine the title and author into the query
query = f'intitle:"{title}" inauthor:"{author}"'

params = {
'q': query,
'fields': 'items(volumeInfo)',
'key': books_key
}

r = requests.get(url, params=params)

if r.ok:
    data = r.json()
    book = data.get("items", [])
    all_books.extend(book)

# %%
### just a test trial for another book from PEN data
all_books = []

title = 'Heartstopper'

# Combine the title and author into the query
query = f'intitle:"{title}"'

params = {
'q': query,
'fields': 'items(volumeInfo)',
'key': books_key
}

r = requests.get(url, params=params)
print(r.status_code)

if r.ok:
    data = r.json()
    book = data.get("items", [])
    all_books.extend(book)
# Out:
# 429

# %%
all_books 
# it worked!!! now i can extract JUST the volumeInfo and the accurate title and author
# Out:
# [{'volumeInfo': {'title': 'Ace of Spades',
#    'authors': ['Faridah Àbíké-Íyímídé'],
#    'publisher': 'Feiwel & Friends',
#    'publishedDate': '2021-06-01',
# ...

# %%
### the next problem: the author is in last name, first name. google API doesn't do that :/
  # should i do just the last name or change the whole thing??

# so let's try doing none of that work first
all_books = []

title = 'Ace of Spades'
author = 'Àbíké-Íyímídé, Faridah'

query = f'intitle:"{title}" inauthor:"{author}"'

params = {
'q': query,
'fields': 'items(volumeInfo)',
'key': books_key
}

r = requests.get(url, params=params)

if r.ok:
    data = r.json()
    book = data.get("items", [])
    all_books.extend(book)

all_books
# welp that didn't work :/
# ik that just the first name works, let's try with just the last name
# Out:
# []

# %%
### just trying it with LAST NAME
all_books = []

title = 'Ace of Spades'
author = 'Àbíké-Íyímídé'

query = f'intitle:"{title}" inauthor:"{author}"'

params = {
'q': query,
'fields': 'items(volumeInfo)',
'key': books_key
}

r = requests.get(url, params=params)

if r.ok:
    data = r.json()
    book = data.get("items", [])
    all_books.extend(book)

all_books
# okay this worked!
# Out:
# [{'volumeInfo': {'title': 'Ace of Spades',
#    'authors': ['Faridah Àbíké-Íyímídé'],
#    'publisher': 'Feiwel & Friends',
#    'publishedDate': '2021-06-01',
# ...

# %%
# now how do i just extract the last name?
### adding a new column:LAST NAME to df from PEN
df['Last Name'] = df['Author'].str.split(',').str[0]
df
# Out:
#                                                   Title  \
# 0     Liar, Temptress, Soldier, Spy: Four Women Unde...
# 1                                         Ace of Spades
# 5                                    Clap When You Land
# 6                                            The Poet X
# 14         Uncomfortable Conversations with a Black Boy
# ...                                                 ...
# 3357                   My Life as an Ice Cream Sandwich
# 3358                                   Punching the Air
# 3359              Poisonous, Smelly, and Amazing Plants
# 3360              Bosch: The Garden of Earthly Delights
# 3361           How to Read Italian Renaissance Painting
#
#                       Author Secondary Author(s) Illustrator(s) Translator(s)  \
# 0              Abbott, Karen                 NaN            NaN           NaN
# 1     Àbíké-Íyímídé, Faridah                 NaN            NaN           NaN
# ...

# %%
### just trying out how to iterate through a dataframe
# for book in df:
#     print(df.Title, df.Last_Name)

# we stopped doing this bc its not very nice to do

# %%
######## don't do this you guys
# okay!! let's start with 
### from Google API, getting all info about the banned books (from PEN) 
for book in df:
    title = df.Title
    last_name = df.Last_Name

    query = f'intitle:"{title}" inauthor:"{author}"'

    params = {
    'q': query,
    'fields': 'items(volumeInfo)',
    'key': books_key
    }

    r = requests.get(url, params=params)

    if r.ok:
        data = r.json()
        book = data.get("items", [])
        all_books.extend(book)    
# took 9.8s (yikes)

# %%
print(len(all_books))
type(all_books)
# and also didn't do the whole thing since the len is just 14
# Out:
# 14
# list

# %%
# ... okay that was embarassing, i need to go a couple of time and do max 40 at a time. going to my last code to see how i did that!
# max_results = 40
# total_books_to_fetch = 1557 # len of total unique books from PEN

# all_books = []

# for _, row in df.iterrows():
#     title = row['Title']
#     last_name = row['Last Name']

#     query = f'intitle:"{title}" inauthor:"{author}"'

#     for start_index in range(0, total_books_to_fetch, max_results):
#         params = {
#                 'q': query,
#                 'key': books_key,
#                 'maxResults': 1,
#                 'startIndex': start_index,  # Pagination for multiple pages # just learned about pagination from chat :P
#                 'fields': 'items(volumeInfo)'  # Reduce payload size
#             }

#         r = requests.get(url, params=params)

#         if r.ok:
#             data = r.json()
#             books = data.get("items", [])
#             all_books.extend(books)
#         else:
#             print(f"Request failed for '{title}' at startIndex={start_index} with status {r.status_code}")
#             break

# df_books = pd.json_normalize(all_books)
# print(df_books.head())
# ## i stopped this at 3m 28s and got status 429

# %%
# total_books_to_fetch = 1557 # len of total unique books from PEN

# all_books = []

# # got this from chat
# def find_best_match(books, title):
#     for book in books:
#         volume_info = book.get("volumeInfo", {})
#         book_title = volume_info.get("title", "").lower()
        
#         if title.lower() in book_title:  # Check if title is in the result
#             return book  # Return first relevant match
#     return None  # Return None if no match is found

# # Loop through each row in the dataframe
# for _, row in df.iterrows():
#     title = row["Title"]
#     last_name = row["Last Name"]
#     #last_name = row["Author"].split(",")[0]  # Extract last name

#     # Create search query
#     query = f'intitle:"{title}" inauthor:"{last_name}"'

#     # Define API parameters
#     params = {
#         'q': query,
#         'key': books_key,
#         'maxResults': 40,  # Get up to 40 books to find the best match
#         'fields': 'items(volumeInfo)'
#     }

#     # Make API request
#     r = requests.get(url, params=params)

#     # Process response
#     if r.status_code == 200:
#         data = r.json()
#         books = data.get("items", [])

#         best_match = find_best_match(books, title)
#         if best_match:
#             all_books.append(best_match)  # Store only the best match
#     else:
#         print(f"Request failed for '{title}' with status {r.status_code}")

# # Convert results to DataFrame
# df_books = pd.json_normalize(all_books)

# %%
##### as much as this code helped, i didn't save any of the data i collected from the api and it all went to waste as my api key met its limit and the for loop halted :/
##### don't be like me and save your data in a csv! (as I've shown below)
### this code from chat SAVED my life
# Iterate through each row in the dataframe (replace 'df' with your actual dataframe)
for _, row in df.iterrows():
    title = row['Title']
    last_name = row['Last Name']

    query = f'intitle:"{title}" inauthor:"{last_name}"'

    params = {
        'q': query,
        'fields': 'items(volumeInfo)',
        'key': books_key
    }

    r = requests.get(url, params=params)

    if r.ok:
        data = r.json()
        books = data.get("items", [])
        all_books.extend(books)
        print(f"Fetched data for {title} by {last_name}")
    else:
        print(f"Failed to fetch data for {title} by {last_name}")

    # Sleep for 1 second to avoid hitting the rate limit
    time.sleep(1) ### life saver -3- !!

# Now you can process all_books which contains the information for all the books
print(f"Fetched data for {len(all_books)} books")


# have a csv for each 40 books, an if statement

# %%
import csv

# %%
### saving data into csv as we go to avoid hitting limit

# here are all the things that is inside volumeInfo
#['title', 'subtitle', 'authors', 'publisher', 'publishedDate', 'description', 'industryIdentifiers', 'readingModes', 'pageCount', 'printType', 
# 'categories', 'averageRating', 'ratingsCount', 'maturityRating', 'allowAnonLogging', 'contentVersion', 'panelizationSummary', 'imageLinks', 
# 'language', 'previewLink', 'infoLink', 'canonicalVolumeLink']

output_file = "books.csv"

with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Author", "Published Date", "Categories", "Description", "ISBN_13", "Maturity Rating"])

books = []

for _, row in df.iterrows():
    title = row['Title']
    last_name = row['Last Name']

    query = f'intitle:"{title}" inauthor:"{last_name}"'

    params = {
        'q': query,
        'fields': 'items(volumeInfo)',
        'key': books_key
    }

    r = requests.get(url, params=params)

    if r.status_code == 429:
        print("Rate limit exceeded. Stopping search.")
        break

    if r.ok:
        data = r.json() # converting API response from JSON format into a python dictionary 
        items = data.get("items", []) 
        # This retrieves the "items" key from the data dictionary.
        # If "items" exists, it contains a list of book results from the search query.
        # If "items" does not exist (e.g., no books found), it defaults to an empty list [] to avoid errors.

        for item in items: ### what does items look like?
            info = item.get("volumeInfo", {})

            # Extract ISBN_13 if available
            isbn_13 = ""
            for identifier in info.get("industryIdentifiers", []):
                if identifier.get("type") == "ISBN_13":
                    isbn_13 = identifier.get("identifier", "")
                    break  # Stop after finding the first ISBN_13

            book_data = [
                info.get("title", ""),
                ", ".join(info.get("authors", [])),
                info.get("publishedDate", ""),
                ", ".join(info.get("categories", [])) if "categories" in info else "",
                info.get("description", ""),
                isbn_13,
                info.get("maturityRating", "")
            ]

            books.append(book_data)

            # Append to CSV file
            with open(output_file, mode="a", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow(book_data)

        print(f"Fetched data for {title} by {last_name}")

    else:
        print(f"Failed to fetch data for {title} by {last_name}")

    # Sleep for 1 second to avoid hitting the rate limit
    time.sleep(1)

print(f"Fetched data for {len(books)} books")

# %% [markdown]
# #### managed to get a total of 4098 books from this! cross-referencing with the PEN Book Bans, we are at got 2400 out of 3365 total books.

# %% [markdown]
# ## Data Cleaning

# %%
books_df = pd.read_csv('books.csv')
print(len(books_df))
books_df.head()
# Out:
# 4098
#                            Title                 Author Published Date  \
# 0  Liar, Temptress, Soldier, Spy           Karen Abbott     2014-09-02
# 1  Liar, Temptress, Soldier, Spy           Karen Abbott           2014
# 2                  Ace of Spades  Faridah Àbíké-Íyímídé     2021-06-01
# 3       Ace of Spades Sneak Peek  Faridah Àbíké-Íyímídé     2021-03-05
# 4             Clap When You Land      Elizabeth Acevedo     2020-05-05
#
#             Categories                                        Description  \
# 0              History  Karen Abbott, the New York Times bestselling a...
# 1              HISTORY  The never-before-told story of four real-life ...
# 2  Young Adult Fiction  Gossip Girl meets Get Out in Ace of Spades, a ...
# 3  Young Adult Fiction  Download a FREE sneak peek of Ace of Spades by...
# 4  Young Adult Fiction  In a novel-in-verse that brims with grief and ...
#
#         ISBN_13 Maturity Rating
# 0  9.780062e+12      NOT_MATURE
# ...

# %% [markdown]
# ##### notes for future:
#
# maybe a future project would be to have a dataset/ code that shows you what book got banned where and when? with all the details gained from the google api? so a combined dataset between PEN and google API.

# %% [markdown]
# # Coming soon: APA's Most Challenged Books of the decade

# %% [markdown]
# ### 2010 to 2019

# %%
book_list_2019 = [
    {"Title": "The Absolutely True Diary of a Part-Time Indian", "Author": "Sherman Alexie"},
    {"Title": "Captain Underpants", "Author": "Dav Pilkey"},
    {"Title": "Thirteen Reasons Why", "Author": "Jay Asher"},
    {"Title": "Looking for Alaska", "Author": "John Green"},
    {"Title": "George", "Author": "Alex Gino"},
    {"Title": "And Tango Makes Three", "Author": "Justin Richardson and Peter Parnell"},
    {"Title": "Drama", "Author": "Raina Telgemeier"},
    {"Title": "Fifty Shades of Grey", "Author": "E. L. James"},
    {"Title": "Internet Girls", "Author": "Lauren Myracle"},
    {"Title": "The Bluest Eye", "Author": "Toni Morrison"},
    {"Title": "The Kite Runner", "Author": "Khaled Hosseini"},
    {"Title": "Hunger Games", "Author": "Suzanne Collins"},
    {"Title": "I Am Jazz", "Author": "Jazz Jennings and Jessica Herthel"},
    {"Title": "The Perks of Being a Wallflower", "Author": "Stephen Chbosky"},
    {"Title": "To Kill a Mockingbird", "Author": "Harper Lee"},
    {"Title": "Bone", "Author": "Jeff Smith"},
    {"Title": "The Glass Castle", "Author": "Jeannette Walls"},
    {"Title": "Two Boys Kissing", "Author": "David Levithan"},
    {"Title": "A Day in the Life of Marlon Bundo", "Author": "Jill Twiss"},
    {"Title": "Sex is a Funny Word", "Author": "Cory Silverberg"},
    {"Title": "Alice McKinley", "Author": "Phyllis Reynolds Naylor"},
    {"Title": "It's Perfectly Normal", "Author": "Robie H. Harris"},
    {"Title": "Nineteen Minutes", "Author": "Jodi Picoult"},
    {"Title": "Scary Stories", "Author": "Alvin Schwartz"},
    {"Title": "Speak", "Author": "Laurie Halse Anderson"},
    {"Title": "Brave New World", "Author": "Aldous Huxley"},
    {"Title": "Beyond Magenta: Transgender Teens Speak Out", "Author": "Susan Kuklin"},
    {"Title": "Of Mice and Men", "Author": "John Steinbeck"},
    {"Title": "The Handmaid's Tale", "Author": "Margaret Atwood"},
    {"Title": "The Hate U Give", "Author": "Angie Thomas"},
    {"Title": "Fun Home: A Family Tragicomic", "Author": "Alison Bechdel"},
    {"Title": "It's a Book", "Author": "Lane Smith"},
    {"Title": "The Adventures of Huckleberry Finn", "Author": "Mark Twain"},
    {"Title": "The Things They Carried", "Author": "Tim O'Brien"},
    {"Title": "What My Mother Doesn't Know", "Author": "Sonya Sones"},
    {"Title": "A Child Called 'It'", "Author": "Dave Pelzer"},
    {"Title": "Bad Kitty", "Author": "Nick Bruel"},
    {"Title": "Crank", "Author": "Ellen Hopkins"},
    {"Title": "Nickel and Dimed", "Author": "Barbara Ehrenreich"},
    {"Title": "Persepolis", "Author": "Marjane Satrapi"},
    {"Title": "The Adventures of Super Diaper Baby", "Author": "Dav Pilkey"},
    {"Title": "This Day in June", "Author": "Gayle E. Pitman"},
    {"Title": "This One Summer", "Author": "Mariko Tamaki"},
    {"Title": "A Bad Boy Can Be Good For A Girl", "Author": "Tanya Lee Stone"},
    {"Title": "Beloved", "Author": "Toni Morrison"},
    {"Title": "Goosebumps", "Author": "R.L. Stine"},
    {"Title": "In Our Mothers' House", "Author": "Patricia Polacco"},
    {"Title": "Lush", "Author": "Natasha Friend"},
    {"Title": "The Catcher in the Rye", "Author": "J.D. Salinger"},
    {"Title": "The Color Purple", "Author": "Alice Walker"},
    {"Title": "The Curious Incident of the Dog in the Night-Time", "Author": "Mark Haddon"},
    {"Title": "The Holy Bible", "Author": "Various Authors"},
    {"Title": "This Book is Gay", "Author": "Juno Dawson"},
    {"Title": "Eleanor & Park", "Author": "Rainbow Rowell"},
    {"Title": "Extremely Loud & Incredibly Close", "Author": "Jonathan Safran Foer"},
    {"Title": "Gossip Girl", "Author": "Cecily von Ziegesar"},
    {"Title": "House of Night", "Author": "P.C. Cast"},
    {"Title": "My Mom's Having A Baby", "Author": "Dori Hillestad Butler"},
    {"Title": "Neonomicon", "Author": "Alan Moore"},
    {"Title": "The Dirty Cowboy", "Author": "Amy Timberlake"},
    {"Title": "The Giver", "Author": "Lois Lowry"},
    {"Title": "Anne Frank: Diary of a Young Girl", "Author": "Anne Frank"},
    {"Title": "Bless Me, Ultima", "Author": "Rudolfo Anaya"},
    {"Title": "Draw Me a Star", "Author": "Eric Carle"},
    {"Title": "Dreaming In Cuban", "Author": "Cristina Garcia"},
    {"Title": "Fade", "Author": "Lisa McMann"},
    {"Title": "The Family Book", "Author": "Todd Parr"},
    {"Title": "Feed", "Author": "M.T. Anderson"},
    {"Title": "Go the Fuck to Sleep", "Author": "Adam Mansbach"},
    {"Title": "Habibi", "Author": "Craig Thompson"},
    {"Title": "House of the Spirits", "Author": "Isabel Allende"},
    {"Title": "Jacob's New Dress", "Author": "Sarah Hoffman"},
    {"Title": "Lolita", "Author": "Vladimir Nabokov"},
    {"Title": "Monster", "Author": "Walter Dean Myers"},
    {"Title": "Nasreen’s Secret School", "Author": "Jeanette Winter"},
    {"Title": "Saga", "Author": "Brian K. Vaughan"},
    {"Title": "Stuck in the Middle", "Author": "Ariel Schrag"},
    {"Title": "The Kingdom of Little Wounds", "Author": "Susann Cokal"},
    {"Title": "1984", "Author": "George Orwell"},
    {"Title": "A Clockwork Orange", "Author": "Anthony Burgess"},
    {"Title": "Almost Perfect", "Author": "Brian Katcher"},
    {"Title": "Awakening", "Author": "Kate Chopin"},
    {"Title": "Burned", "Author": "Ellen Hopkins"},
    {"Title": "Ender's Game", "Author": "Orson Scott Card"},
    {"Title": "Fallen Angels", "Author": "Walter Dean Myers"},
    {"Title": "Glass", "Author": "Ellen Hopkins"},
    {"Title": "Heather Has Two Mommies", "Author": "Lesléa Newman"},
    {"Title": "I Know Why the Caged Bird Sings", "Author": "Maya Angelou"},
    {"Title": "Madeline and the Gypsies", "Author": "Ludwig Bemelmans"},
    {"Title": "My Princess Boy", "Author": "Cheryl Kilodavis"},
    {"Title": "Prince and Knight", "Author": "Daniel Haack"},
    {"Title": "Revolutionary Voices: A Multicultural Queer Youth Anthology", "Author": "Amy Sonnie"},
    {"Title": "Skippyjon Jones", "Author": "Judith Schachner"},
    {"Title": "So Far from the Bamboo Grove", "Author": "Yoko Kawashima Watkins"},
    {"Title": "The Color of Earth", "Author": "Tong-hwa Kim"},
    {"Title": "The Librarian of Basra", "Author": "Jeanette Winter"},
    {"Title": "The Walking Dead", "Author": "Robert Kirkman"},
    {"Title": "Tricks", "Author": "Ellen Hopkins"},
    {"Title": "Uncle Bobby’s Wedding", "Author": "Sarah S Brannen"},
    {"Title": "Year of Wonders", "Author": "Geraldine Brooks"}
]

# %%
book_list_2009 = [
    {"Title": "Harry Potter", "Author": "J.K. Rowling"},
    {"Title": "Alice", "Author": "Phyllis Reynolds Naylor"},
    {"Title": "The Chocolate War", "Author": "Robert Cormier"},
    {"Title": "And Tango Makes Three", "Author": "Justin Richardson and Peter Parnell"},
    {"Title": "Of Mice and Men", "Author": "John Steinbeck"},
    {"Title": "I Know Why the Caged Bird Sings", "Author": "Maya Angelou"},
    {"Title": "Scary Stories", "Author": "Alvin Schwartz"},
    {"Title": "His Dark Materials", "Author": "Philip Pullman"},
    {"Title": "ttyl; ttfn; l8r g8r", "Author": "Lauren Myracle"},
    {"Title": "The Perks of Being a Wallflower", "Author": "Stephen Chbosky"},
    {"Title": "Fallen Angels", "Author": "Walter Dean Myers"},
    {"Title": "It’s Perfectly Normal", "Author": "Robie Harris"},
    {"Title": "Captain Underpants", "Author": "Dav Pilkey"},
    {"Title": "The Adventures of Huckleberry Finn", "Author": "Mark Twain"},
    {"Title": "The Bluest Eye", "Author": "Toni Morrison"},
    {"Title": "Forever", "Author": "Judy Blume"},
    {"Title": "The Color Purple", "Author": "Alice Walker"},
    {"Title": "Go Ask Alice", "Author": "Anonymous"},
    {"Title": "Catcher in the Rye", "Author": "J.D. Salinger"},
    {"Title": "King and King", "Author": "Linda de Haan"},
    {"Title": "To Kill A Mockingbird", "Author": "Harper Lee"},
    {"Title": "Gossip Girl", "Author": "Cecily von Ziegesar"},
    {"Title": "The Giver", "Author": "Lois Lowry"},
    {"Title": "In the Night Kitchen", "Author": "Maurice Sendak"},
    {"Title": "Killing Mr. Griffen", "Author": "Lois Duncan"},
    {"Title": "Beloved", "Author": "Toni Morrison"},
    {"Title": "My Brother Sam Is Dead", "Author": "James Lincoln Collier"},
    {"Title": "Bridge To Terabithia", "Author": "Katherine Paterson"},
    {"Title": "The Face on the Milk Carton", "Author": "Caroline B. Cooney"},
    {"Title": "We All Fall Down", "Author": "Robert Cormier"},
    {"Title": "What My Mother Doesn’t Know", "Author": "Sonya Sones"},
    {"Title": "Bless Me, Ultima", "Author": "Rudolfo Anaya"},
    {"Title": "Snow Falling on Cedars", "Author": "David Guterson"},
    {"Title": "The Earth, My Butt, and Other Big, Round Things", "Author": "Carolyn Mackler"},
    {"Title": "Angus, Thongs, and Full Frontal Snogging", "Author": "Louise Rennison"},
    {"Title": "Brave New World", "Author": "Aldous Huxley"},
    {"Title": "It’s So Amazing", "Author": "Robie Harris"},
    {"Title": "Arming America", "Author": "Michael Bellasiles"},
    {"Title": "Kaffir Boy", "Author": "Mark Mathabane"},
    {"Title": "Life is Funny", "Author": "E.R. Frank"},
    {"Title": "Whale Talk", "Author": "Chris Crutcher"},
    {"Title": "The Fighting Ground", "Author": "Avi"},
    {"Title": "Blubber", "Author": "Judy Blume"},
    {"Title": "Athletic Shorts", "Author": "Chris Crutcher"},
    {"Title": "Crazy Lady", "Author": "Jane Leslie Conly"},
    {"Title": "Slaughterhouse-Five", "Author": "Kurt Vonnegut"},
    {"Title": "The Adventures of Super Diaper Baby", "Author": "Dav Pilkey"},
    {"Title": "Rainbow Boys", "Author": "Alex Sanchez"},
    {"Title": "One Flew Over the Cuckoo’s Nest", "Author": "Ken Kesey"},
    {"Title": "The Kite Runner", "Author": "Khaled Hosseini"},
    {"Title": "Daughters of Eve", "Author": "Lois Duncan"},
    {"Title": "The Great Gilly Hopkins", "Author": "Katherine Paterson"},
    {"Title": "You Hear Me?", "Author": "Betsy Franco"},
    {"Title": "The Facts Speak for Themselves", "Author": "Brock Cole"},
    {"Title": "Summer of My German Soldier", "Author": "Bette Green"},
    {"Title": "When Dad Killed Mom", "Author": "Julius Lester"},
    {"Title": "Blood and Chocolate", "Author": "Annette Curtis Klause"},
    {"Title": "Fat Kid Rules the World", "Author": "K.L. Going"},
    {"Title": "Olive’s Ocean", "Author": "Kevin Henkes"},
    {"Title": "Speak", "Author": "Laurie Halse Anderson"},
    {"Title": "Draw Me A Star", "Author": "Eric Carle"},
    {"Title": "The Stupids", "Author": "Harry Allard"},
    {"Title": "The Terrorist", "Author": "Caroline B. Cooney"},
    {"Title": "Mick Harte Was Here", "Author": "Barbara Park"},
    {"Title": "The Things They Carried", "Author": "Tim O’Brien"},
    {"Title": "Roll of Thunder, Hear My Cry", "Author": "Mildred Taylor"},
    {"Title": "A Time to Kill", "Author": "John Grisham"},
    {"Title": "Always Running", "Author": "Luis Rodriguez"},
    {"Title": "Fahrenheit 451", "Author": "Ray Bradbury"},
    {"Title": "Harris and Me", "Author": "Gary Paulsen"},
    {"Title": "Junie B. Jones", "Author": "Barbara Park"},
    {"Title": "Song of Solomon", "Author": "Toni Morrison"},
    {"Title": "What’s Happening to My Body Book", "Author": "Lynda Madaras"},
    {"Title": "The Lovely Bones", "Author": "Alice Sebold"},
    {"Title": "Anastasia", "Author": "Lois Lowry"},
    {"Title": "A Prayer for Owen Meany", "Author": "John Irving"},
    {"Title": "Crazy", "Author": "Benjamin Lebert"},
    {"Title": "The Joy of Gay Sex", "Author": "Dr. Charles Silverstein"},
    {"Title": "The Upstairs Room", "Author": "Johanna Reiss"},
    {"Title": "A Day No Pigs Would Die", "Author": "Robert Newton Peck"},
    {"Title": "Black Boy", "Author": "Richard Wright"},
    {"Title": "Deal With It!", "Author": "Esther Drill"},
    {"Title": "Detour for Emmy", "Author": "Marilyn Reynolds"},
    {"Title": "So Far From the Bamboo Grove", "Author": "Yoko Watkins"},
    {"Title": "Staying Fat for Sarah Byrnes", "Author": "Chris Crutcher"},
    {"Title": "Cut", "Author": "Patricia McCormick"},
    {"Title": "Tiger Eyes", "Author": "Judy Blume"},
    {"Title": "The Handmaid’s Tale", "Author": "Margaret Atwood"},
    {"Title": "Friday Night Lights", "Author": "H.G. Bissenger"},
    {"Title": "A Wrinkle in Time", "Author": "Madeline L’Engle"},
    {"Title": "Julie of the Wolves", "Author": "Jean Craighead George"},
    {"Title": "The Boy Who Lost His Face", "Author": "Louis Sachar"},
    {"Title": "Bumps in the Night", "Author": "Harry Allard"},
    {"Title": "Goosebumps", "Author": "R.L. Stine"},
    {"Title": "Shade’s Children", "Author": "Garth Nix"},
    {"Title": "Grendel", "Author": "John Gardner"},
    {"Title": "The House of the Spirits", "Author": "Isabel Allende"},
    {"Title": "I Saw Esau", "Author": "Iona Opte"},
    {"Title": "Are You There, God? It’s Me, Margaret", "Author": "Judy Blume"},
    {"Title": "America", "Author": "E.R. Frank"}
]

# %%
book_list_1999 = [
    {"Title": "Scary Stories", "Author": "Alvin Schwartz"},
    {"Title": "Daddy’s Roommate", "Author": "Michael Willhoite"},
    {"Title": "I Know Why the Caged Bird Sings", "Author": "Maya Angelou"},
    {"Title": "The Chocolate War", "Author": "Robert Cormier"},
    {"Title": "The Adventures of Huckleberry Finn", "Author": "Mark Twain"},
    {"Title": "Of Mice and Men", "Author": "John Steinbeck"},
    {"Title": "Forever", "Author": "Judy Blume"},
    {"Title": "Bridge to Terabithia", "Author": "Katherine Paterson"},
    {"Title": "Heather Has Two Mommies", "Author": "Leslea Newman"},
    {"Title": "The Catcher in the Rye", "Author": "J.D. Salinger"},
    {"Title": "The Giver", "Author": "Lois Lowry"},
    {"Title": "My Brother Sam is Dead", "Author": "James Lincoln Collier and Christopher Collier"},
    {"Title": "It’s Perfectly Normal", "Author": "Robie Harris"},
    {"Title": "Alice", "Author": "Phyllis Reynolds Naylor"},
    {"Title": "Goosebumps", "Author": "R.L. Stine"},
    {"Title": "A Day No Pigs Would Die", "Author": "Robert Newton Peck"},
    {"Title": "The Color Purple", "Author": "Alice Walker"},
    {"Title": "Sex", "Author": "Madonna"},
    {"Title": "Earth’s Children", "Author": "Jean M. Auel"},
    {"Title": "The Great Gilly Hopkins", "Author": "Katherine Paterson"},
    {"Title": "In the Night Kitchen", "Author": "Maurice Sendak"},
    {"Title": "The Witches", "Author": "Roald Dahl"},
    {"Title": "A Wrinkle in Time", "Author": "Madeleine L’Engle"},
    {"Title": "The New Joy of Gay Sex", "Author": "Charles Silverstein"},
    {"Title": "Go Ask Alice", "Author": "Anonymous"},
    {"Title": "The Goats", "Author": "Brock Cole"},
    {"Title": "The Stupids", "Author": "Harry Allard"},
    {"Title": "Anastasia Krupnik", "Author": "Lois Lowry"},
    {"Title": "Final Exit", "Author": "Derek Humphry"},
    {"Title": "Blubber", "Author": "Judy Blume"},
    {"Title": "Halloween ABC", "Author": "Eve Merriam"},
    {"Title": "Julie of the Wolves", "Author": "Jean Craighead George"},
    {"Title": "Kaffir Boy", "Author": "Mark Mathabane"},
    {"Title": "The Bluest Eye", "Author": "Toni Morrison"},
    {"Title": "What’s Happening to my Body? Book for Girls: A Growing-Up Guide for Parents & Daughters", "Author": "Lynda Madaras"},
    {"Title": "Fallen Angels", "Author": "Walter Dean Myers"},
    {"Title": "The Handmaid’s Tale", "Author": "Margaret Atwood"},
    {"Title": "The Outsiders", "Author": "S.E. Hinton"},
    {"Title": "The Pigman", "Author": "Paul Zindel"},
    {"Title": "To Kill a Mockingbird", "Author": "Harper Lee"},
    {"Title": "We All Fall Down", "Author": "Robert Cormier"},
    {"Title": "Deenie", "Author": "Judy Blume"},
    {"Title": "Flowers for Algernon", "Author": "Daniel Keyes"},
    {"Title": "Annie on My Mind", "Author": "Nancy Garden"},
    {"Title": "Beloved", "Author": "Toni Morrison"},
    {"Title": "The Boy Who Lost His Face", "Author": "Louis Sachar"},
    {"Title": "Cross Your Fingers, Spit in Your Hat", "Author": "Alvin Schwartz"},
    {"Title": "Harry Potter", "Author": "J.K. Rowling"},
    {"Title": "Cujo", "Author": "Stephen King"},
    {"Title": "James and the Giant Peach", "Author": "Roald Dahl"},
    {"Title": "A Light in the Attic", "Author": "Shel Silverstein"},
    {"Title": "Ordinary People", "Author": "Judith Guest"},
    {"Title": "American Psycho", "Author": "Bret Easton Ellis"},
    {"Title": "Brave New World", "Author": "Aldous Huxley"},
    {"Title": "Sleeping Beauty Trilogy", "Author": "A.N. Roquelaure (Anne Rice)"},
    {"Title": "Bumps in the Night", "Author": "Harry Allard"},
    {"Title": "Asking About Sex and Growing Up", "Author": "Joanna Cole"},
    {"Title": "What’s Happening to my Body? Book for Boys: A Growing-Up Guide for Parents & Sons", "Author": "Lynda Madaras"},
    {"Title": "The Anarchist Cookbook", "Author": "William Powell"},
    {"Title": "Are You There, God? It’s Me, Margaret", "Author": "Judy Blume"},
    {"Title": "Boys and Sex", "Author": "Wardell Pomeroy"},
    {"Title": "Crazy Lady", "Author": "Jane Conly"},
    {"Title": "Athletic Shorts", "Author": "Chris Crutcher"},
    {"Title": "Killing Mr. Griffin", "Author": "Lois Duncan"},
    {"Title": "Fade", "Author": "Robert Cormier"},
    {"Title": "Guess What?", "Author": "Mem Fox"},
    {"Title": "Slaughterhouse-Five", "Author": "Kurt Vonnegut"},
    {"Title": "Lord of the Flies", "Author": "William Golding"},
    {"Title": "Native Son", "Author": "Richard Wright"},
    {"Title": "Women on Top: How Real Life Has Changed Women’s Fantasies", "Author": "Nancy Friday"},
    {"Title": "Curses, Hexes and Spells", "Author": "Daniel Cohen"},
    {"Title": "On My Honor", "Author": "Marion Dane Bauer"},
    {"Title": "The House of Spirits", "Author": "Isabel Allende"},
    {"Title": "Jack", "Author": "A.M. Homes"},
    {"Title": "Arizona Kid", "Author": "Ron Koertge"},
    {"Title": "Family Secrets", "Author": "Norma Klein"},
    {"Title": "Mommy Laid an Egg", "Author": "Babette Cole"},
    {"Title": "Bless Me, Ultima", "Author": "Rudolfo A. Anaya"},
    {"Title": "Where Did I Come From?", "Author": "Peter Mayle"},
    {"Title": "The Face on the Milk Carton", "Author": "Caroline Cooney"},
    {"Title": "Carrie", "Author": "Stephen King"},
    {"Title": "The Dead Zone", "Author": "Stephen King"},
    {"Title": "The Adventures of Tom Sawyer", "Author": "Mark Twain"},
    {"Title": "Song of Solomon", "Author": "Toni Morrison"},
    {"Title": "Always Running", "Author": "Luis Rodriguez"},
    {"Title": "Private Parts", "Author": "Howard Stern"},
    {"Title": "Where’s Waldo?", "Author": "Martin Hanford"},
    {"Title": "Summer of My German Soldier", "Author": "Bette Greene"},
    {"Title": "Tiger Eyes", "Author": "Judy Blume"},
    {"Title": "Little Black Sambo", "Author": "Helen Bannerman"},
    {"Title": "Pillars of the Earth", "Author": "Ken Follett"},
    {"Title": "Running Loose", "Author": "Chris Crutcher"},
    {"Title": "Sex Education", "Author": "Jenny Davis"},
    {"Title": "Jumper", "Author": "Steven Gould"},
    {"Title": "Christine", "Author": "Stephen King"},
    {"Title": "The Drowning of Stephen Jones", "Author": "Bette Greene"},
    {"Title": "That Was Then, This is Now", "Author": "S.E. Hinton"},
    {"Title": "Girls and Sex", "Author": "Wardell Pomeroy"},
    {"Title": "The Wish Giver", "Author": "Bill Brittain"},
    {"Title": "Jump Ship to Freedom", "Author": "James Lincoln Collier and Christopher Collier"}
]
